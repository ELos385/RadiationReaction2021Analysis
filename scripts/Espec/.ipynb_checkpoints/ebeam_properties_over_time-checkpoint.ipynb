# %%
import matplotlib, os, sys
import matplotlib.font_manager
from matplotlib import rcParams

#import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
from scipy.io import loadmat
from pathlib import Path
from scipy.stats import mode
from scipy.interpolate import interp1d, RectBivariateSpline, interp2d, CloughTocher2DInterpolator, interpn
from scipy.integrate import cumtrapz
from scipy.optimize import minimize

sys.path.append('../../..')
sys.path.append('../..')
sys.path.append('../')

from tqdm import tqdm
from setup import *
from modules.Espec import *#get_raw_image
from modules.GammaSpec.GammaSpecProc import *
from lib.general_tools import imagesc, load_object, calc_COW, d, smooth_gauss, compute_percentile_from_dist
from lib.general_tools import choose_cal_file, glob_path, get_file_path, save_object
from lib.analysis_database import Database

plt.style.use('/home/el1103292/GitHub/RadiationReaction2021Analysis/lib/thesis.mplstyle')
DATA_PATH =Path(ROOT_DATA_FOLDER)
DATA_PATH
# Out:
# PosixPath('/data/instrument/GEMINI/2021/App20110008-1/MIRAGE')

# %%
# reads gamma profile analysis
analysis_path = Path(r'/data/analysis/GEMINI/2021/App20110008-1/Results/')
diag = 'GammaProfile'
database_file = analysis_path / f'{diag}_results_main.pkl'
gammaProf_db = Database(database_file,always_load=True)
gammaProf_db.dataframe.head()
# Out:
#                      img_med  img_max
# run            shot
# 20210604/run02 1        99.0    111.0
#                2        99.0    108.0
#                3        98.0    111.0
#                4        99.0    119.0
#                5        99.0    120.0

# %%
def compute_percentile_from_dist(dist, axis, target_percentile):
    
    div=10.0
    N=int(len(dist)/div)
    percentile, energy=np.zeros(N), np.zeros(N)
    dist=dist/np.trapz(dist, axis)
    for i in range(0, N):
        percentile[i]=np.trapz(dist[0:len(axis)-1-int(div)*i], axis[0:len(axis)-1-int(div)*i])
        energy[i]=axis[len(axis)-1-int(div)*i]
        if percentile[i]<target_percentile-0.005:
            break
    percentile_cut=percentile[percentile!=0.0]
    energy_cut=energy[energy!=0.0]
    energy_at_percentile=np.interp(target_percentile, percentile_cut, energy_cut)
    return energy_at_percentile

def compute_peakiness_measure(dQ_dE, E_MeV, color, normalisation_factor_E):
    E_GeV=E_MeV/1000.0
    dQ_dE=dQ_dE*E_GeV/np.trapz(dQ_dE*E_GeV, E_GeV)
    Q_tot=np.trapz(dQ_dE, E_GeV)
    mean_energy_tmp=np.trapz(dQ_dE*E_GeV, E_GeV)/Q_tot
    mean_energy_sqrd_tmp=np.trapz(dQ_dE*E_MeV*E_GeV, E_GeV)/Q_tot
    
    e_at_70th_percentile=compute_percentile_from_dist(dQ_dE, E_GeV, 0.7)
    e_at_50th_percentile=compute_percentile_from_dist(dQ_dE, E_GeV, 0.5)
    E_thresh=e_at_70th_percentile
    indx_near_mean=np.argmin(abs(E_GeV-E_thresh))

    mean_dQ_dE=np.mean(dQ_dE)
    max_over_med_above_thresh=max(dQ_dE[indx_near_mean:])#(max(dQ_dE[indx_near_mean:])-mean_dQ_dE)/mean_dQ_dE
    peakiness_measure=max_over_med_above_thresh
    return peakiness_measure, E_thresh, max(dQ_dE[indx_near_mean:])#peakiness_measure, mean_energy_tmp
    
def get_electron_props(gammaProf_db, get_e_img=False):
    e_img_list = []
    E_90th_percentile=[]
    Qgamma2=[]
    av_gamma2=[]
    peakiness_arr=[]
    Q_energy_thresh=[]
    electron_mean_E=[]
    Q_tot=[]
    time_arr=[]
    
    count=0
    color_arr=['r', 'b', 'g', 'orange', 'cyan', 'magenta']
    
    time_path='/home/el1103292/GitHub/RadiationReaction2021Analysis/lib/shot_2_GSN/'
    times_file=time_path+'%s.pkl'%(run_name[0:8])
    run_no='run18'
    times_data = load_object(times_file)
    times_data_current_run=times_data[run_no]
    all_shot=np.array(times_data_current_run['Shot numbers'])
    all_times=np.array(times_data_current_run['Time'])
    print(all_shot)
    print(all_times)
    times_data_current_run01=times_data['run01']
    all_shotr1=np.array(times_data_current_run['Shot numbers'])
    gsnr1=np.array(times_data_current_run['GSN'])
    all_timesr1=np.array(times_data_current_run['Time'])
    print(gsnr1[0])
    
    
    
#     for n,row in gammaProf_db.dataframe.iterrows():
#         run_name,shot = row.name
#         spectra_path = Path('/data/analysis/GEMINI/2021/App20110008-1/Results/Espec/Spectra') / run_name.replace('/','_')
#         espec_file = spectra_path / f'Shot{shot:04}_spectra.pkl'
        
        
        
#         #get time of shot
        
#         normalisation_factor_E=np.random.uniform(800.0, 1500.0)
#         time_path='/home/el1103292/GitHub/RadiationReaction2021Analysis/lib/shot_2_GSN/'
#         times_file=time_path+'%s.pkl'%(run_name[0:8])
#         run_no=run_name[9:]
#         times_data = load_object(times_file)
#         print('run_no=%s'%run_no)
#         times_data_current_run=times_data[run_no]
#         all_shot=times_data_current_run['Shot numbers']
#         all_times=times_data_current_run['Time']
#         print('all_shot.shape=%s'%[all_shot.shape])
#         print('all_times.shape=%s'%[all_times.shape])
#         print('shot=%s'%shot)
#         idx_shot=np.where(all_shot==shot)
#         print('idx_shot=%s'%idx_shot)
#         current_time=all_times[idx_shot]
#         print('current_time=%s'%current_time)
#         time_arr.append(current_time)
#         current_shot=all_shot[idx_shot]
# #         print(current_shot)
# #         print(current_time)
        
#         if os.path.isfile(espec_file):
#             espec_data = load_object(espec_file)
#             E_MeV,y_mrad,spec1, dWdE1_JperGeV = espec_data['E_MeV'],espec_data['y1_mrad'],espec_data['spec1'],espec_data['dWdE1_JperGeV']
#             if get_e_img==True:
#                 y0 = y_mrad[np.argmax(np.sum(spec1,axis=1))]
#                 y_mrad_disp = np.linspace(-4.5,4.5,100)
#                 spec_img = RectBivariateSpline(y_mrad-y0,E_MeV,spec1)(y_mrad_disp,E_MeV)
#                 e_img_list.append(spec_img)
                
#             #90th percentile e
#             e_at_90th_percentile=compute_percentile_from_dist(dWdE1_JperGeV, E_MeV/1000.0, 0.9)
#             E_90th_percentile.append(e_at_90th_percentile)

#             #charge 
#             dQ_dE=np.trapz(spec1,x=y_mrad,axis=0)
#             Q_tot_tmp=np.trapz(dQ_dE, E_MeV)
#             Q_tot.append(Q_tot_tmp)

#             #Q gamma_sqrd
#             Qgamma2_tmp=np.trapz(dQ_dE*E_MeV/0.511*E_MeV/0.511, E_MeV)
#             Qgamma2.append(Qgamma2_tmp)
#             av_gamma2.append(Qgamma2_tmp/Q_tot_tmp)

#             #mean energy per electron
#             electron_mean_E_tmp=np.trapz(dQ_dE*(E_MeV), E_MeV)/Q_tot_tmp
#             electron_mean_E.append(electron_mean_E_tmp)

#             #peakiness metric
#             peakiness, energy_thresh_tmp, max_height=compute_peakiness_measure(dQ_dE, E_MeV, "r", normalisation_factor_E)
#             Q_energy_thresh.append(energy_thresh_tmp)
#             peakiness_arr.append(peakiness)

#         #             if count<6:
#         #                 plt.plot(np.full(100, energy_thresh_tmp/rand_norm), np.linspace(0.0, 15.0, 100), color=color_arr[count])
#         #                 E_GeV=E_MeV/(1000.0*rand_norm)
#         #                 dEW_DE=dQ_dE*E_GeV/np.trapz(dQ_dE*E_GeV, E_GeV)
#         #                 plt.plot(E_GeV, dEW_DE, color=color_arr[count])
#         #                 count+=1
# #         else:
# #             e_img_list.append(spec_img*np.nan)
# #             E_90th_percentile_hits.append(np.nan)
# #     plt.xticks(fontsize=12)
# #     plt.yticks(fontsize=12)
# #     plt.xlabel("Blinded Energy (a.u.)", fontsize=16)
# #     plt.ylabel("Normalised Charge per\n Relative Energy Spread (a.u.)", fontsize=16)
#     print(np.array(E_90th_percentile).shape)
#     return np.array(e_img_list), np.array(E_90th_percentile), np.array(Qgamma2), np.array(av_gamma2), np.array(peakiness_arr), np.array(Q_energy_thresh), np.array(electron_mean_E), np.array(Q_tot), np.array(time_arr)


# np.random.seed(67)
# rand_norm=np.random.uniform(0.1, 10.0)



# e_img_list, E_90th_percentile, Qgamma2_hits, av_gamma2_hits, peakiness_arr, Q_energy_thresh, electron_mean_E, Q_tot, times=get_electron_props(gammaProf_db, False)
# Out:
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=1
# idx_shot=[0]
# current_time=['2021-06-04 15:22:25']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=2
# idx_shot=[1]
# current_time=['2021-06-04 15:28:46']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=3
# idx_shot=[2]
# current_time=['2021-06-04 15:29:06']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=4
# idx_shot=[3]
# current_time=['2021-06-04 15:29:26']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=5
# idx_shot=[4]
# current_time=['2021-06-04 15:29:46']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=6
# idx_shot=[5]
# current_time=['2021-06-04 15:30:06']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=7
# idx_shot=[6]
# current_time=['2021-06-04 15:30:26']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=8
# idx_shot=[7]
# current_time=['2021-06-04 15:30:46']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=9
# idx_shot=[8]
# current_time=['2021-06-04 15:31:06']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=10
# idx_shot=[9]
# current_time=['2021-06-04 15:31:26']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=11
# idx_shot=[10]
# current_time=['2021-06-04 15:31:46']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=12
# idx_shot=[11]
# current_time=['2021-06-04 15:32:06']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=13
# idx_shot=[12]
# current_time=['2021-06-04 15:32:26']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=14
# idx_shot=[13]
# current_time=['2021-06-04 15:32:47']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=15
# idx_shot=[14]
# current_time=['2021-06-04 15:33:07']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=16
# idx_shot=[15]
# current_time=['2021-06-04 15:33:27']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=17
# idx_shot=[16]
# current_time=['2021-06-04 15:33:47']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=18
# idx_shot=[17]
# current_time=['2021-06-04 15:34:07']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=19
# idx_shot=[18]
# current_time=['2021-06-04 15:34:27']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=20
# idx_shot=[19]
# current_time=['2021-06-04 15:34:47']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=21
# idx_shot=[20]
# current_time=['2021-06-04 15:35:08']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=22
# idx_shot=[21]
# current_time=['2021-06-04 15:35:28']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=23
# idx_shot=[22]
# current_time=['2021-06-04 15:35:48']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=24
# idx_shot=[23]
# current_time=['2021-06-04 15:36:08']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=25
# idx_shot=[24]
# current_time=['2021-06-04 15:36:28']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=26
# idx_shot=[25]
# current_time=['2021-06-04 15:36:48']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=27
# idx_shot=[26]
# current_time=['2021-06-04 15:37:08']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=28
# idx_shot=[27]
# current_time=['2021-06-04 15:37:28']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=29
# idx_shot=[28]
# current_time=['2021-06-04 15:37:48']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=30
# idx_shot=[29]
# current_time=['2021-06-04 15:38:08']
# run_no=run02
# all_shot.shape=[(31,)]
# all_times.shape=[(31,)]
# shot=31
# idx_shot=[30]
# current_time=['2021-06-04 15:38:28']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=1
# idx_shot=[0]
# current_time=['2021-06-04 15:38:48']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=2
# idx_shot=[1]
# current_time=['2021-06-04 15:41:09']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=3
# idx_shot=[2]
# current_time=['2021-06-04 15:41:29']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=4
# idx_shot=[3]
# current_time=['2021-06-04 15:41:49']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=5
# idx_shot=[4]
# current_time=['2021-06-04 15:42:09']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=6
# idx_shot=[5]
# current_time=['2021-06-04 15:42:29']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=7
# idx_shot=[6]
# current_time=['2021-06-04 15:43:09']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=8
# idx_shot=[7]
# current_time=['2021-06-04 15:43:29']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=9
# idx_shot=[8]
# current_time=['2021-06-04 15:43:49']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=10
# idx_shot=[9]
# current_time=['2021-06-04 15:44:09']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=11
# idx_shot=[10]
# current_time=['2021-06-04 15:44:29']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=12
# idx_shot=[11]
# current_time=['2021-06-04 15:44:49']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=13
# idx_shot=[12]
# current_time=['2021-06-04 15:45:09']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=14
# idx_shot=[13]
# current_time=['2021-06-04 15:45:29']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=15
# idx_shot=[14]
# current_time=['2021-06-04 15:45:50']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=16
# idx_shot=[15]
# current_time=['2021-06-04 15:46:10']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=17
# idx_shot=[16]
# current_time=['2021-06-04 15:47:10']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=18
# idx_shot=[17]
# current_time=['2021-06-04 15:47:30']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=19
# idx_shot=[18]
# current_time=['2021-06-04 15:47:50']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=20
# idx_shot=[19]
# current_time=['2021-06-04 15:48:10']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=21
# idx_shot=[20]
# current_time=['2021-06-04 15:48:30']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=22
# idx_shot=[21]
# current_time=['2021-06-04 15:48:50']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=23
# idx_shot=[22]
# current_time=['2021-06-04 15:49:10']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=24
# idx_shot=[23]
# current_time=['2021-06-04 15:49:30']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=25
# idx_shot=[24]
# current_time=['2021-06-04 15:49:50']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=26
# idx_shot=[25]
# current_time=['2021-06-04 15:50:10']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=27
# idx_shot=[26]
# current_time=['2021-06-04 15:50:30']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=28
# idx_shot=[27]
# current_time=['2021-06-04 15:50:50']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=29
# idx_shot=[28]
# current_time=['2021-06-04 15:51:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=30
# idx_shot=[29]
# current_time=['2021-06-04 15:51:31']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=31
# idx_shot=[30]
# current_time=['2021-06-04 15:51:51']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=32
# idx_shot=[31]
# current_time=['2021-06-04 15:52:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=33
# idx_shot=[32]
# current_time=['2021-06-04 15:52:31']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=34
# idx_shot=[33]
# current_time=['2021-06-04 15:52:51']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=35
# idx_shot=[34]
# current_time=['2021-06-04 15:53:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=36
# idx_shot=[35]
# current_time=['2021-06-04 15:53:31']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=37
# idx_shot=[36]
# current_time=['2021-06-04 15:53:51']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=38
# idx_shot=[37]
# current_time=['2021-06-04 15:54:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=39
# idx_shot=[38]
# current_time=['2021-06-04 15:54:31']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=40
# idx_shot=[39]
# current_time=['2021-06-04 15:54:51']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=41
# idx_shot=[40]
# current_time=['2021-06-04 15:55:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=42
# idx_shot=[41]
# current_time=['2021-06-04 15:55:31']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=43
# idx_shot=[42]
# current_time=['2021-06-04 15:55:51']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=44
# idx_shot=[43]
# current_time=['2021-06-04 15:56:11']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=45
# idx_shot=[44]
# current_time=['2021-06-04 15:56:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=46
# idx_shot=[45]
# current_time=['2021-06-04 15:56:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=47
# idx_shot=[46]
# current_time=['2021-06-04 15:57:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=48
# idx_shot=[47]
# current_time=['2021-06-04 15:57:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=49
# idx_shot=[48]
# current_time=['2021-06-04 15:57:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=50
# idx_shot=[49]
# current_time=['2021-06-04 15:58:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=51
# idx_shot=[50]
# current_time=['2021-06-04 15:58:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=52
# idx_shot=[51]
# current_time=['2021-06-04 15:58:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=53
# idx_shot=[52]
# current_time=['2021-06-04 15:59:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=54
# idx_shot=[53]
# current_time=['2021-06-04 15:59:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=55
# idx_shot=[54]
# current_time=['2021-06-04 15:59:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=56
# idx_shot=[55]
# current_time=['2021-06-04 16:00:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=57
# idx_shot=[56]
# current_time=['2021-06-04 16:00:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=58
# idx_shot=[57]
# current_time=['2021-06-04 16:01:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=59
# idx_shot=[58]
# current_time=['2021-06-04 16:02:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=60
# idx_shot=[59]
# current_time=['2021-06-04 16:02:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=61
# idx_shot=[60]
# current_time=['2021-06-04 16:02:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=62
# idx_shot=[61]
# current_time=['2021-06-04 16:03:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=63
# idx_shot=[62]
# current_time=['2021-06-04 16:03:32']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=64
# idx_shot=[63]
# current_time=['2021-06-04 16:03:52']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=65
# idx_shot=[64]
# current_time=['2021-06-04 16:04:12']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=66
# idx_shot=[65]
# current_time=['2021-06-04 16:04:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=67
# idx_shot=[66]
# current_time=['2021-06-04 16:04:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=68
# idx_shot=[67]
# current_time=['2021-06-04 16:05:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=69
# idx_shot=[68]
# current_time=['2021-06-04 16:05:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=70
# idx_shot=[69]
# current_time=['2021-06-04 16:05:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=71
# idx_shot=[70]
# current_time=['2021-06-04 16:06:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=72
# idx_shot=[71]
# current_time=['2021-06-04 16:06:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=73
# idx_shot=[72]
# current_time=['2021-06-04 16:06:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=74
# idx_shot=[73]
# current_time=['2021-06-04 16:07:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=75
# idx_shot=[74]
# current_time=['2021-06-04 16:07:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=76
# idx_shot=[75]
# current_time=['2021-06-04 16:07:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=77
# idx_shot=[76]
# current_time=['2021-06-04 16:08:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=78
# idx_shot=[77]
# current_time=['2021-06-04 16:08:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=79
# idx_shot=[78]
# current_time=['2021-06-04 16:08:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=80
# idx_shot=[79]
# current_time=['2021-06-04 16:09:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=81
# idx_shot=[80]
# current_time=['2021-06-04 16:09:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=82
# idx_shot=[81]
# current_time=['2021-06-04 16:09:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=83
# idx_shot=[82]
# current_time=['2021-06-04 16:10:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=84
# idx_shot=[83]
# current_time=['2021-06-04 16:10:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=85
# idx_shot=[84]
# current_time=['2021-06-04 16:10:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=86
# idx_shot=[85]
# current_time=['2021-06-04 16:11:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=87
# idx_shot=[86]
# current_time=['2021-06-04 16:11:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=88
# idx_shot=[87]
# current_time=['2021-06-04 16:11:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=89
# idx_shot=[88]
# current_time=['2021-06-04 16:12:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=90
# idx_shot=[89]
# current_time=['2021-06-04 16:12:33']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=91
# idx_shot=[90]
# current_time=['2021-06-04 16:12:53']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot=92
# idx_shot=[91]
# current_time=['2021-06-04 16:13:13']
# run_no=run03
# all_shot.shape=[(106,)]
# all_times.shape=[(106,)]
# shot
41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=57
# idx_shot=[56]
# current_time=['2021-06-21 05:13:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=58
# idx_shot=[57]
# current_time=['2021-06-21 05:13:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=59
# idx_shot=[58]
# current_time=['2021-06-21 05:13:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=60
# idx_shot=[59]
# current_time=['2021-06-21 05:14:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=61
# idx_shot=[60]
# current_time=['2021-06-21 05:14:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=62
# idx_shot=[61]
# current_time=['2021-06-21 05:14:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=63
# idx_shot=[62]
# current_time=['2021-06-21 05:15:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=64
# idx_shot=[63]
# current_time=['2021-06-21 05:15:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=65
# idx_shot=[64]
# current_time=['2021-06-21 05:15:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=66
# idx_shot=[65]
# current_time=['2021-06-21 05:16:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=67
# idx_shot=[66]
# current_time=['2021-06-21 05:17:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=68
# idx_shot=[67]
# current_time=['2021-06-21 05:17:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=69
# idx_shot=[68]
# current_time=['2021-06-21 05:18:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=70
# idx_shot=[69]
# current_time=['2021-06-21 05:18:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=71
# idx_shot=[70]
# current_time=['2021-06-21 05:18:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=72
# idx_shot=[71]
# current_time=['2021-06-21 05:19:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=73
# idx_shot=[72]
# current_time=['2021-06-21 05:19:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=74
# idx_shot=[73]
# current_time=['2021-06-21 05:19:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=75
# idx_shot=[74]
# current_time=['2021-06-21 05:20:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=76
# idx_shot=[75]
# current_time=['2021-06-21 05:20:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=77
# idx_shot=[76]
# current_time=['2021-06-21 05:20:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=78
# idx_shot=[77]
# current_time=['2021-06-21 05:21:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=79
# idx_shot=[78]
# current_time=['2021-06-21 05:21:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=80
# idx_shot=[79]
# current_time=['2021-06-21 05:21:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=81
# idx_shot=[80]
# current_time=['2021-06-21 05:22:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=82
# idx_shot=[81]
# current_time=['2021-06-21 05:22:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=83
# idx_shot=[82]
# current_time=['2021-06-21 05:22:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=84
# idx_shot=[83]
# current_time=['2021-06-21 05:23:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=85
# idx_shot=[84]
# current_time=['2021-06-21 05:23:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=86
# idx_shot=[85]
# current_time=['2021-06-21 05:23:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=87
# idx_shot=[86]
# current_time=['2021-06-21 05:24:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=88
# idx_shot=[87]
# current_time=['2021-06-21 05:25:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=89
# idx_shot=[88]
# current_time=['2021-06-21 05:25:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=90
# idx_shot=[89]
# current_time=['2021-06-21 05:25:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=91
# idx_shot=[90]
# current_time=['2021-06-21 05:26:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=92
# idx_shot=[91]
# current_time=['2021-06-21 05:26:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=93
# idx_shot=[92]
# current_time=['2021-06-21 05:26:41']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=94
# idx_shot=[93]
# current_time=['2021-06-21 05:27:01']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=95
# idx_shot=[94]
# current_time=['2021-06-21 05:27:21']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=96
# idx_shot=[95]
# current_time=['2021-06-21 05:27:42']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=97
# idx_shot=[96]
# current_time=['2021-06-21 05:28:02']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=98
# idx_shot=[97]
# current_time=['2021-06-21 05:28:22']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=99
# idx_shot=[98]
# current_time=['2021-06-21 05:28:42']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=100
# idx_shot=[99]
# current_time=['2021-06-21 05:29:02']
# run_no=run17
# all_shot.shape=[(101,)]
# all_times.shape=[(101,)]
# shot=101
# idx_shot=[100]
# current_time=['2021-06-21 05:29:22']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=1
# idx_shot=[0]
# current_time=['2021-06-21 05:29:42']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=2
# idx_shot=[1]
# current_time=['2021-06-21 05:30:02']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=3
# idx_shot=[2]
# current_time=['2021-06-21 05:30:22']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=4
# idx_shot=[3]
# current_time=['2021-06-21 05:30:42']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=5
# idx_shot=[4]
# current_time=['2021-06-21 05:31:02']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=6
# idx_shot=[5]
# current_time=['2021-06-21 05:31:22']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=7
# idx_shot=[6]
# current_time=['2021-06-21 05:31:42']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=8
# idx_shot=[7]
# current_time=['2021-06-21 05:32:02']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=9
# idx_shot=[8]
# current_time=['2021-06-21 05:32:22']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=10
# idx_shot=[9]
# current_time=['2021-06-21 05:32:42']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=11
# idx_shot=[10]
# current_time=['2021-06-21 05:33:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=12
# idx_shot=[11]
# current_time=['2021-06-21 05:33:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=13
# idx_shot=[12]
# current_time=['2021-06-21 05:33:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=14
# idx_shot=[13]
# current_time=['2021-06-21 05:34:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=15
# idx_shot=[14]
# current_time=['2021-06-21 05:34:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=16
# idx_shot=[15]
# current_time=['2021-06-21 05:34:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=17
# idx_shot=[16]
# current_time=['2021-06-21 05:35:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=18
# idx_shot=[17]
# current_time=['2021-06-21 05:35:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=19
# idx_shot=[18]
# current_time=['2021-06-21 05:35:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=20
# idx_shot=[19]
# current_time=['2021-06-21 05:36:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=21
# idx_shot=[20]
# current_time=['2021-06-21 05:36:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=22
# idx_shot=[21]
# current_time=['2021-06-21 05:36:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=23
# idx_shot=[22]
# current_time=['2021-06-21 05:37:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=24
# idx_shot=[23]
# current_time=['2021-06-21 05:37:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=25
# idx_shot=[24]
# current_time=['2021-06-21 05:37:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=26
# idx_shot=[25]
# current_time=['2021-06-21 05:38:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=27
# idx_shot=[26]
# current_time=['2021-06-21 05:38:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=28
# idx_shot=[27]
# current_time=['2021-06-21 05:38:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=29
# idx_shot=[28]
# current_time=['2021-06-21 05:39:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=30
# idx_shot=[29]
# current_time=['2021-06-21 05:39:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=31
# idx_shot=[30]
# current_time=['2021-06-21 05:39:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=32
# idx_shot=[31]
# current_time=['2021-06-21 05:40:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=33
# idx_shot=[32]
# current_time=['2021-06-21 05:40:23']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=34
# idx_shot=[33]
# current_time=['2021-06-21 05:40:43']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=35
# idx_shot=[34]
# current_time=['2021-06-21 05:41:03']
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=36
# idx_shot=[35]
# current_time=[nan]
# run_no=run18
# all_shot.shape=[(50,)]
# all_times.shape=[(36,)]
# shot=37
# idx_shot=[36]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-7b3316afdc15> in <module>
#     132
#     133
# --> 134 e_img_list, E_90th_percentile, Qgamma2_hits, av_gamma2_hits, peakiness_arr, Q_energy_thresh, electron_mean_E, Q_tot, times=get_electron_props(gammaProf_db, False)
#     135
#     136
#
# <ipython-input-4-7b3316afdc15> in get_electron_props(gammaProf_db, get_e_img)
#      71         idx_shot=np.where(all_shot==shot)
#      72         print('idx_shot=%s'%idx_shot)
# ---> 73         current_time=all_times[idx_shot]
#      74         print('current_time=%s'%current_time)
#      75         time_arr.append(current_time)
#
# IndexError: index 36 is out of bounds for axis 0 with size 36

# %%
plt.plot(times, Q_tot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2e73cc4c8428> in <module>
# ----> 1 plt.plot(times, Q_tot)
#       2 plt.show()
#
# NameError: name 'times' is not defined
